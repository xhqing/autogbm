# %%
import pandas as pd

# %%
data = pd.read_csv("all_results_20200507.csv")

# %%
data.shape
# Out:
# (1532, 18)

# %%
data.head()
# Out:
#    Unnamed: 0           phase  time_budget  \
# 0           0  ablation-study         1200
# 1           1  ablation-study         1200
# 2           2  ablation-study         1200
# 3           3  ablation-study         1200
# 4           4  ablation-study         1200
#
#                        participant_name  submission_id task_name  \
# 0  DeepBlueAI_minus_adaptive_strategies             30       Ray
# 1  DeepBlueAI_minus_adaptive_strategies             30     Fiona
# 2  DeepBlueAI_minus_adaptive_strategies             30     Oreal
# 3  DeepBlueAI_minus_adaptive_strategies             30       Tal
# 4  DeepBlueAI_minus_adaptive_strategies             30     Bilal
#
#                                           nauc_score  \
# 0  [0.14083989087493487, 0.19540063923712991, 0.2...
# 1  [0.12810055221139316, 0.27966970242511446, 0.3...
# 2  [0.49793496425644523, 0.559914141208435, 0.528...
# 3  [0.767590153544734, 0.9076296729166324, 0.9423...
# ...

# %%
data.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'phase',
#  'time_budget',
#  'participant_name',
#  'submission_id',
#  'task_name',
#  'nauc_score',
#  'accuracy_score',
#  'timestamps',
#  'alc_score',
#  'duration',
#  'nauc_mean',
#  'nauc_std',
#  'nauc_var',
#  'alc_mean',
#  'alc_std',
#  'alc_var',
#  'challenge']

# %%
data.drop("Unnamed: 0", axis=1, inplace=True)

# %%
data.head()
# Out:
#             phase  time_budget                      participant_name  \
# 0  ablation-study         1200  DeepBlueAI_minus_adaptive_strategies
# 1  ablation-study         1200  DeepBlueAI_minus_adaptive_strategies
# 2  ablation-study         1200  DeepBlueAI_minus_adaptive_strategies
# 3  ablation-study         1200  DeepBlueAI_minus_adaptive_strategies
# 4  ablation-study         1200  DeepBlueAI_minus_adaptive_strategies
#
#    submission_id task_name                                         nauc_score  \
# 0             30       Ray  [0.14083989087493487, 0.19540063923712991, 0.2...
# 1             30     Fiona  [0.12810055221139316, 0.27966970242511446, 0.3...
# 2             30     Oreal  [0.49793496425644523, 0.559914141208435, 0.528...
# 3             30       Tal  [0.767590153544734, 0.9076296729166324, 0.9423...
# 4             30     Bilal  [0.9072128698902531, 0.9594210495750981, 0.967...
#
#                                       accuracy_score  \
# ...

# %%
data["phase"].unique()
# Out:
# array(['ablation-study', 'image', 'tabular', 'text', 'time', 'video',
#        'baseline3', 'bug_fixed', 'feedback', 'final', 'final2',
#        'new_0406', 'top4'], dtype=object)

# %%
data.query("phase=='tabular'")
# Out:
#        phase  time_budget participant_name  submission_id task_name  \
# 274  tabular         1200       DeepWisdom              3     adult
# 275  tabular         1200       DeepWisdom              3   dilbert
# 276  tabular         1200       DeepWisdom              3    digits
# 277  tabular         1200       DeepWisdom              3  madeline
# 278  tabular         1200       DeepWisdom              3     Barak
# 279  tabular         1200       DeepWisdom              3     Bilal
# 280  tabular         1200       DeepWisdom              3     carla
# 281  tabular         1200        baseline3              1     adult
# 282  tabular         1200        baseline3              1   dilbert
# 283  tabular         1200        baseline3              1    digits
# 284  tabular         1200        baseline3              1  madeline
# 285  tabular         1200        baseline3              1     Barak
# 286  tabular         1200        baseline3              1     Bilal
# ...

# %%
data.query("phase=='top4'")
# Out:
#      phase  time_budget participant_name  submission_id task_name  \
# 1262  top4         1200       DeepBlueAI             11       Ray
# 1263  top4         1200       DeepBlueAI             11     Fiona
# 1264  top4         1200       DeepBlueAI             11     Oreal
# 1265  top4         1200       DeepBlueAI             11       Tal
# 1266  top4         1200       DeepBlueAI             11     Bilal
# ...    ...          ...              ...            ...       ...
# 1527  top4         1200        frozenmad              8  Cucumber
# 1528  top4         1200        frozenmad              8      Yolo
# 1529  top4         1200        frozenmad              8     Marge
# 1530  top4         1200        frozenmad              8    Viktor
# 1531  top4         1200        frozenmad              8     carla
#
#                                              nauc_score  \
# 1262  [0.18678452699659576, 0.16623962194749597, 0.2...
# 1263  [0.2472963331657072, 0.3822145714234153, 0.367...
# ...

# %%
data["time_budget"].unique()
# Out:
# array([1200])

# %%
data["participant_name"].unique()
# Out:
# array(['DeepBlueAI_minus_adaptive_strategies',
#        'DeepBlueAI_minus_all_three', 'DeepBlueAI_minus_ensemble_learning',
#        'DeepBlueAI_minus_scoring_time_reduction',
#        'DeepWisdom_minus_dataaugmentation',
#        'DeepWisdom_minus_dataloading', 'DeepWisdom_minus_metalearning',
#        'DeepWisdom_minus_metalearning_dataloading',
#        'automl_freiburg_minus_autofolio_HPO',
#        'automl_freiburg_minus_metalearning_generalist',
#        'automl_freiburg_minus_metalearning_random_selector', 'DeepWisdom',
#        'baseline3', 'Zhengying', 'Inspur_AutoDL', 'Kon', 'surromind',
#        'team_zhaw', 'DeepBlueAI', 'LEAD', 'LIWENBO', 'Ohyeah', 'PASA_NJU',
#        'avengers', 'ben', 'bugloss', 'franklinlee', 'franklintli',
#        'frozenmad', 'kimjooeun', 'notthebrightest', 'sondaseul',
#        'automl_freiburg'], dtype=object)
